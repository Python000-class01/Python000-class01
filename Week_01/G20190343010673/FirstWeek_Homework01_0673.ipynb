# %% [markdown]
# # Python训练营-第一周作业-0673

# %% [markdown]
# ## 作业内容
# ### （1）安装并使用 requests、bs4 库，爬取豆瓣电影 Top250 的电影名称、评分、短评数量和前 5 条热门短评，并以 UTF-8 字符集保存到 csv 格式的文件中。

# %% [markdown]
# ### ==================================== 分割线 ========================================

# %%
# 导入库
from urllib import request, parse
from bs4 import BeautifulSoup
import socket
import requests
import re

# %%
url = 'https://movie.douban.com/top250'

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    # "Accept-Encoding": "gzip, deflate, sdch",
    "Accept-Language": "zh-CN,zh;q=0.9",
    "Connection": "close",
    "Cookie": "_gauges_unique_hour=1; _gauges_unique_day=1; _gauges_unique_month=1; _gauges_unique_year=1; _gauges_unique=1;",
    "Referer": "http://httpbin.org/",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36"
}

response = requests.get(url=url, headers=headers)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-cmn-Hans" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
# 豆瓣电影 Top 250
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#     <link rel="apple-touch-icon" href="https://img9.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
#     <link href="https://img9.doubanio.com/f/shire/3e5dfc68b0f376484c50cf08a58bbca3700911dc/css/douban.css" rel="stylesheet" type="text/css">
# ...

# %%
movie_pattern = re.compile(r'<a href="(.*?)".*?"title">(.*?)</span>.*?"rating_num" property="v:average">(.*?)</span>.*?<span>(.*?)</span>', re.S)
movie_results = re.findall(movie_pattern, response.text)
print(movie_results)
# Out:
# [('https://accounts.douban.com/passport/login?source=movie', '肖申克的救赎', '9.7', '1912847人评价'), ('https://movie.douban.com/subject/1291546/', '霸王别姬', '9.6', '1407066人评价'), ('https://movie.douban.com/subject/1292720/', '阿甘正传', '9.5', '1454006人评价'), ('https://movie.douban.com/subject/1295644/', '这个杀手不太冷', '9.4', '1650112人评价'), ('https://movie.douban.com/subject/1292063/', '美丽人生', '9.5', '922823人评价'), ('https://movie.douban.com/subject/1292722/', '泰坦尼克号', '9.4', '1399686人评价'), ('https://movie.douban.com/subject/1291561/', '千与千寻', '9.3', '1495321人评价'), ('https://movie.douban.com/subject/1295124/', '辛德勒的名单', '9.5', '744069人评价'), ('https://movie.douban.com/subject/3541415/', '盗梦空间', '9.3', '1402499人评价'), ('https://movie.douban.com/subject/3011091/', '忠犬八公的故事', '9.4', '963894人评价'), ('https://movie.douban.com/subject/1292001/', '海上钢琴师', '9.3', '1164495人评价'), ('https://movie.douban.com/subject/2131459/', '机器人总动员', '9.3', '925009人评价'), ('https://movie.douban.com/subject/3793023/', '三傻大闹宝莱坞', '9.2
# ...

# %%
# 解析title_results，拿到电影短评
List = []
index = 0
for movie_result in movie_results[1:]:
    url, title, mark, people = movie_result
    # 获取短评数
    response = requests.get(url=url, headers=headers)
    details_pattern = re.compile(r'<div class="mod-hd">.*?<h2>.*?<i class="">.*?<span class="pl">.*?<a href=.*?>全部(.*?)条</a>', re.S)
    details_results = re.findall(details_pattern, response.text)
    # print(details_results)
    # comments_pattern = re.compile(r'<span class="comment-info">.*?<p>.*?"short">(.*?)</span></p>', re.S)
    # comments_results = re.findall(comments_pattern, response.text)
    # print(comments_results)
    for detail_result in details_results:
        num = detail_result
        print('链接:{0}，电影名:{1}，评分:{2}，评论人数:{3}，{1}的短评数:{4} \n '.format(url, title, mark, people, num))
#         index += 1
#         str = 'TOP %d <<%s%s%s%s%s>> ' % (index, url, title, mark, people, num)
#         List.append(str)
# Out:
# 链接:https://movie.douban.com/subject/1291546/，电影名:霸王别姬，评分:9.6，评论人数:1407066人评价，霸王别姬的短评数: 279762
#
# 链接:https://movie.douban.com/subject/1292720/，电影名:阿甘正传，评分:9.5，评论人数:1454006人评价，阿甘正传的短评数: 222261
#
# 链接:https://movie.douban.com/subject/1295644/，电影名:这个杀手不太冷，评分:9.4，评论人数:1650112人评价，这个杀手不太冷的短评数: 271449
#
# 链接:https://movie.douban.com/subject/1292063/，电影名:美丽人生，评分:9.5，评论人数:922823人评价，美丽人生的短评数: 190642

# %%
import csv

writer = csv.writer(open("../Save/movie.csv", 'w', newline=''))
fields = ('url', 'title', 'mark', 'people', 'num')
writer.writelines(List, fields)

for obj in List:
    file_write_obj.writelines(obj)
    file_write_obj.write('\n')
